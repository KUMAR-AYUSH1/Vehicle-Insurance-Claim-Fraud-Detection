# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('balanced.csv')

# %%
df.sample(10)
# Out:
#       Suspicious_Report     Sex MaritalStatus  RepNumber  Age  \
# 1067                  1    Male       Married         12   53
# 647                   1    Male       Married          1   66
# 532                   1  Female       Married          2   52
# 19                    1  Female        Single         15   34
# 1340                  0    Male       Married          1   46
# 912                   1    Male       Married         11   51
# 801                   1    Male       Married         16   50
# 544                   1  Female        Single          8   29
# 867                   1    Male       Married         12   54
# 1056                  1    Male       Married         10   41
#
#       High_Risk_Individual  FraudFound_P
# 1067                     0             1
# 647                      0             0
# 532                      0             0
# 19                       0             0
# 1340                     0             1
# ...

# %%
df['RepNumber'].describe()
# Out:
# count    1408.000000
# mean        8.322443
# std         4.646541
# min         1.000000
# 25%         4.000000
# 50%         8.000000
# 75%        12.000000
# max        16.000000
# Name: RepNumber, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1408 entries, 0 to 1407
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Suspicious_Report     1408 non-null   int64
#  1   Sex                   1408 non-null   object
#  2   MaritalStatus         1408 non-null   object
#  3   RepNumber             1408 non-null   int64
#  4   Age                   1408 non-null   int64
#  5   High_Risk_Individual  1408 non-null   int64
#  6   FraudFound_P          1408 non-null   int64
# dtypes: int64(5), object(2)
# memory usage: 77.1+ KB
